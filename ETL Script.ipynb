# %% [markdown]
# # ETL using BigQuery

# %% [markdown]
# ## Importing Libraries

# %%
from google.cloud import bigquery
import pandas as pd
from datetime import datetime
import os
import google.auth
from google.oauth2 import service_account
from google.cloud import bigquery_storage
import google.cloud.bigquery.magics
import pandas_gbq

# %% [markdown]
# ## Loading Credentials file

# %%
credentials1 = service_account.Credentials.from_service_account_file("eighth-alchemy-382219-a8d58d2f86d6.json")

# %% [markdown]
# # Loading Dataset

# %%
df = pd.read_excel('HR Dataset - DWH.xlsx', sheet_name='HR Dataset')

# %%
df.head()
# Out:
#           Employee_Name  Employee_Number State   Zip        DOB  Age     Sex  \
# 0            Brown, Mia       1103024456    MA  1450 1985-11-24   32  Female
# 1  LaRotonda, William         1106026572    MA  1460 1984-04-26   33    Male
# 2      Steans, Tyrone         1302053333    MA  2703 1986-09-01   31    Male
# 3       Howard, Estelle       1211050782    MA  2170 1985-09-16   32  Female
# 4           Singh, Nan        1307059817    MA  2330 1988-05-19   29  Female
#
#   MaritalDesc CitizenDesc Hispanic_Latino  ... Date_of_Hire  \
# 0     Married  US Citizen              No  ...   2008-10-27
# 1    Divorced  US Citizen              No  ...   2014-01-06
# 2      Single  US Citizen              No  ...   2014-09-29
# 3     Married  US Citizen              No  ...   2015-02-16
# 4      Single  US Citizen              No  ...   2015-05-01
#
#   Date_of_Termination       Reason_For_Term Employment_Status     Department  \
# 0                 NaT  N/A - still employed            Active  Admin Offices
# 1                 NaT  N/A - still employed            Active  Admin Offices
# 2                 NaT  N/A - still employed            Active  Admin Offices
# 3          2015-04-15  N/A - still employed            Active  Admin Offices
# 4                 NaT  N/A - still employed            Active  Admin Offices
#
#                    Position Pay_Rate        Manager_Name  \
# 0              Accountant I    28.50  Brandon R. LeBlanc
# 1              Accountant I    23.00  Brandon R. LeBlanc
# 2              Accountant I    29.00  Brandon R. LeBlanc
# 3  Administrative Assistant    21.50  Brandon R. LeBlanc
# 4  Administrative Assistant    16.56  Brandon R. LeBlanc
#
#           Employee_Source         Performance_Score
# 0      Diversity Job Fair               Fully Meets
# 1      Website Banner Ads               Fully Meets
# 2         Internet Search               Fully Meets
# 3  Pay Per Click - Google  N/A- too early to review
# 4      Website Banner Ads  N/A- too early to review
#
# [5 rows x 21 columns]

# %%
df['Date_of_Termination'] = df['Date_of_Termination'].fillna(datetime(9999, 12, 31))

# %%
df['Reason_For_Term'] = df['Reason_For_Term'].str.replace('N/A - ', '')

# %%
df['Performance_Score'] = df['Performance_Score'].str.replace('N/A- ', '')

# %%
df[['First_Name', 'Last_Name']] = df['Employee_Name'].str.split(',', expand=True)

# drop the original Employee Name column
df.drop('Employee_Name', axis=1, inplace=True)

# reorder the columns to have the new columns first
df = df[['First_Name', 'Last_Name'] + list(df.columns[:-2])]

# %%
df1 = pd.read_excel('HR Dataset - DWH.xlsx', sheet_name='HR_data')

# %%
df1.head()
# Out:
#           Employee_Name  Employee_Number  MarriedID  MaritalStatusID  \
# 0            Brown, Mia       1103024456          1                1
# 1  LaRotonda, William         1106026572          0                2
# 2      Steans, Tyrone         1302053333          0                0
# 3       Howard, Estelle       1211050782          1                1
# 4           Singh, Nan        1307059817          0                0
#
#    GenderID  EmpStatus_ID  DeptID  Perf_ScoreID  Age  Pay_Rate  ...  \
# 0         0             1       1             3   30     28.50  ...
# 1         1             1       1             3   34     23.00  ...
# 2         1             1       1             3   31     29.00  ...
# 3         0             1       1             9   32     21.50  ...
# 4         0             1       1             9   30     16.56  ...
#
#   Date_of_Hire  Days_Employed Date_of_Termination       Reason_For_Term  \
# 0   2008-10-27           3317                 NaT  N/A - still employed
# 1   2014-01-06           1420                 NaT  N/A - still employed
# 2   2014-09-29           1154                 NaT  N/A - still employed
# 3   2015-02-16             58          2015-04-15  N/A - still employed
# 4   2015-05-01            940                 NaT  N/A - still employed
#
#   Employment_Status     Department                  Position  \
# 0            Active  Admin Offices              Accountant I
# 1            Active  Admin Offices              Accountant I
# 2            Active  Admin Offices              Accountant I
# 3            Active  Admin Offices  Administrative Assistant
# 4            Active  Admin Offices  Administrative Assistant
#
#          Manager_Name         Employee_Source         Performance_Score
# 0  Brandon R. LeBlanc      Diversity Job Fair               Fully Meets
# 1  Brandon R. LeBlanc      Website Banner Ads               Fully Meets
# 2  Brandon R. LeBlanc         Internet Search               Fully Meets
# 3  Brandon R. LeBlanc  Pay Per Click - Google  N/A- too early to review
# 4  Brandon R. LeBlanc      Website Banner Ads  N/A- too early to review
#
# [5 rows x 28 columns]

# %%
df1['Reason_For_Term'] = df1['Reason_For_Term'].str.replace('N/A - ', '')
df1['Performance_Score'] = df1['Performance_Score'].str.replace('N/A- ', '')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Employee_Name        310 non-null    object
#  1   Employee_Number      310 non-null    int64
#  2   MarriedID            310 non-null    int64
#  3   MaritalStatusID      310 non-null    int64
#  4   GenderID             310 non-null    int64
#  5   EmpStatus_ID         310 non-null    int64
#  6   DeptID               310 non-null    int64
#  7   Perf_ScoreID         310 non-null    int64
#  8   Age                  310 non-null    int64
#  9   Pay_Rate             310 non-null    float64
#  10  State                310 non-null    object
#  11  Zip                  310 non-null    int64
#  12  DOB                  310 non-null    datetime64[ns]
#  13  Sex                  310 non-null    object
#  14  MaritalDesc          310 non-null    object
#  15  CitizenDesc          310 non-null    object
#  16  Hispanic_Latino      310 non-null    object
#  17  RaceDesc             310 non-null    object
#  18  Date_of_Hire         310 non-null    datetime64[ns]
#  19  Days_Employed        310 non-null    int64
#  20  Date_of_Termination  103 non-null    datetime64[ns]
#  21  Reason_For_Term      310 non-null    object
#  22  Employment_Status    310 non-null    object
#  23  Department           310 non-null    object
#  24  Position             310 non-null    object
#  25  Manager_Name         310 non-null    object
#  26  Employee_Source      310 non-null    object
#  27  Performance_Score    310 non-null    object
# dtypes: datetime64[ns](3), float64(1), int64(10), object(14)
# memory usage: 67.9+ KB

# %%
merged_df = pd.merge(df, df1, on='Employee_Number', how='inner')

# %%
merged_df.head()
# Out:
#   First_Name   Last_Name  Employee_Number State_x  Zip_x      DOB_x  Age_x  \
# 0      Brown         Mia       1103024456      MA   1450 1985-11-24     32
# 1  LaRotonda   William         1106026572      MA   1460 1984-04-26     33
# 2     Steans    Tyrone         1302053333      MA   2703 1986-09-01     31
# 3     Howard     Estelle       1211050782      MA   2170 1985-09-16     32
# 4      Singh        Nan        1307059817      MA   2330 1988-05-19     29
#
#     Sex_x MaritalDesc_x CitizenDesc_x  ... Date_of_Hire_y Days_Employed  \
# 0  Female       Married    US Citizen  ...     2008-10-27          3317
# 1    Male      Divorced    US Citizen  ...     2014-01-06          1420
# 2    Male        Single    US Citizen  ...     2014-09-29          1154
# 3  Female       Married    US Citizen  ...     2015-02-16            58
# 4  Female        Single    US Citizen  ...     2015-05-01           940
#
#   Date_of_Termination_y Reason_For_Term_y Employment_Status_y   Department_y  \
# 0                   NaT    still employed              Active  Admin Offices
# 1                   NaT    still employed              Active  Admin Offices
# 2                   NaT    still employed              Active  Admin Offices
# 3            2015-04-15    still employed              Active  Admin Offices
# 4                   NaT    still employed              Active  Admin Offices
#
#                  Position_y      Manager_Name_y       Employee_Source_y  \
# 0              Accountant I  Brandon R. LeBlanc      Diversity Job Fair
# 1              Accountant I  Brandon R. LeBlanc      Website Banner Ads
# 2              Accountant I  Brandon R. LeBlanc         Internet Search
# 3  Administrative Assistant  Brandon R. LeBlanc  Pay Per Click - Google
# 4  Administrative Assistant  Brandon R. LeBlanc      Website Banner Ads
#
#    Performance_Score_y
# 0          Fully Meets
# 1          Fully Meets
# 2          Fully Meets
# 3  too early to review
# 4  too early to review
#
# [5 rows x 49 columns]

# %%
merged_df.columns
# Out:
# Index(['First_Name', 'Last_Name', 'Employee_Number', 'State_x', 'Zip_x',
#        'DOB_x', 'Age_x', 'Sex_x', 'MaritalDesc_x', 'CitizenDesc_x',
#        'Hispanic_Latino_x', 'RaceDesc_x', 'Date_of_Hire_x',
#        'Date_of_Termination_x', 'Reason_For_Term_x', 'Employment_Status_x',
#        'Department_x', 'Position_x', 'Pay_Rate_x', 'Manager_Name_x',
#        'Employee_Source_x', 'Performance_Score_x', 'Employee_Name',
#        'MarriedID', 'MaritalStatusID', 'GenderID', 'EmpStatus_ID', 'DeptID',
#        'Perf_ScoreID', 'Age_y', 'Pay_Rate_y', 'State_y', 'Zip_y', 'DOB_y',
#        'Sex_y', 'MaritalDesc_y', 'CitizenDesc_y', 'Hispanic_Latino_y',
#        'RaceDesc_y', 'Date_of_Hire_y', 'Days_Employed',
#        'Date_of_Termination_y', 'Reason_For_Term_y', 'Employment_Status_y',
#        'Department_y', 'Position_y', 'Manager_Name_y', 'Employee_Source_y',
#        'Performance_Score_y'],
#       dtype='object')

# %%
repeating_columns = ['Sex_y','Age_y','Pay_Rate_y','State_y','Zip_y','DOB_y','MaritalDesc_y','CitizenDesc_y', 'Hispanic_Latino_y',
       'RaceDesc_y', 'Date_of_Hire_y','Date_of_Termination_y', 'Reason_For_Term_y', 'Employment_Status_y',
       'Department_y', 'Position_y', 'Manager_Name_y', 'Employee_Source_y',
       'Performance_Score_y']

# %%
merged_df = merged_df.drop(repeating_columns, axis=1)

# %%
merged_df.columns
# Out:
# Index(['First_Name', 'Last_Name', 'Employee_Number', 'State_x', 'Zip_x',
#        'DOB_x', 'Age_x', 'Sex_x', 'MaritalDesc_x', 'CitizenDesc_x',
#        'Hispanic_Latino_x', 'RaceDesc_x', 'Date_of_Hire_x',
#        'Date_of_Termination_x', 'Reason_For_Term_x', 'Employment_Status_x',
#        'Department_x', 'Position_x', 'Pay_Rate_x', 'Manager_Name_x',
#        'Employee_Source_x', 'Performance_Score_x', 'Employee_Name',
#        'MarriedID', 'MaritalStatusID', 'GenderID', 'EmpStatus_ID', 'DeptID',
#        'Perf_ScoreID', 'Days_Employed'],
#       dtype='object')

# %%
merged_df.columns = [col.replace('_x', '') for col in merged_df.columns]

# %%
merged_df = merged_df.drop('Employee_Name',axis=1)

# %%
merged_df
# Out:
#      First_Name   Last_Name  Employee_Number State   Zip        DOB  Age  \
# 0         Brown         Mia       1103024456    MA  1450 1985-11-24   32
# 1     LaRotonda   William         1106026572    MA  1460 1984-04-26   33
# 2        Steans    Tyrone         1302053333    MA  2703 1986-09-01   31
# 3        Howard     Estelle       1211050782    MA  2170 1985-09-16   32
# 4         Singh        Nan        1307059817    MA  2330 1988-05-19   29
# ..          ...         ...              ...   ...   ...        ...  ...
# 298   Patronick        Luke       1112030979    MA  1844 1979-02-20   38
# 299       Saada       Adell       1012023185    MA  2132 1986-07-24   31
# 300       Szabo      Andrew       1201031324    MA  2140 1983-05-06   34
# 301        True      Edward       1102024057    MA  2451 1983-06-14   34
# 302  Sweetwater        Alex       1001644719    MA  2184 1966-11-22   51
#
#         Sex MaritalDesc  CitizenDesc  ...        Manager_Name  \
# 0    Female     Married   US Citizen  ...  Brandon R. LeBlanc
# 1      Male    Divorced   US Citizen  ...  Brandon R. LeBlanc
# 2      Male      Single   US Citizen  ...  Brandon R. LeBlanc
# 3    Female     Married   US Citizen  ...  Brandon R. LeBlanc
# 4    Female      Single   US Citizen  ...  Brandon R. LeBlanc
# ..      ...         ...          ...  ...                 ...
# 298    Male      Single   US Citizen  ...     Alex Sweetwater
# 299  Female     Married   US Citizen  ...     Alex Sweetwater
# 300    Male      Single   US Citizen  ...     Alex Sweetwater
# 301    Male      Single  Non-Citizen  ...     Alex Sweetwater
# 302    Male      Single   US Citizen  ...     Jennifer Zamora
#
#                        Employee_Source    Performance_Score MarriedID  \
# 0                   Diversity Job Fair          Fully Meets         1
# 1                   Website Banner Ads          Fully Meets         0
# 2                      Internet Search          Fully Meets         0
# 3               Pay Per Click - Google  too early to review         1
# 4                   Website Banner Ads  too early to review         0
# ..                                 ...                  ...       ...
# 298                 Diversity Job Fair              Exceeds         0
# 299             Pay Per Click - Google          Fully Meets         1
# 300                           MBTA ads          Exceptional         0
# 301                 Diversity Job Fair          Fully Meets         0
# 302  Search Engine - Google Bing Yahoo          Fully Meets         0
#
#     MaritalStatusID GenderID EmpStatus_ID DeptID  Perf_ScoreID Days_Employed
# 0                 1        0            1      1             3          3317
# 1                 2        1            1      1             3          1420
# 2                 0        1            1      1             3          1154
# 3                 1        0            1      1             9            58
# 4                 0        0            1      1             9           940
# ..              ...      ...          ...    ...           ...           ...
# 298               0        1            5      4             4          1400
# 299               1        0            1      4             3          1847
# 300               0        1            1      4             5          1238
# 301               0        1            5      4             3           421
# 302               0        1            1      4             3          2295
#
# [303 rows x 29 columns]

# %%
salary_data = pd.read_excel('HR Dataset - DWH.xlsx', sheet_name='Salary_data')

# %%
salary_data
# Out:
#                         Position    Min     Mid     Max  Unnamed: 4  \
# 0       Administrative Assistant  30000   40000   50000         NaN
# 1   Sr. Administrative Assistant  35000   45000   55000         NaN
# 2                   Accountant I  42274   51425   62299         NaN
# 3                  Accountant II  50490   62158   74658         NaN
# 4                 Sr. Accountant  63264   76988   92454         NaN
# 5               Network Engineer  50845   66850   88279         NaN
# 6           Sr. Network Engineer  79428   99458  120451         NaN
# 7         Database Administrator  50569   68306   93312         NaN
# 8                        Sr. DBA  92863  116007  139170         NaN
# 9        Production Technician I  30000   40000   50000         NaN
# 10      Production Technician II  38000   48000   58000         NaN
# 11    Lead Production Technician  45000   55000   65000         NaN
#
#     Unnamed: 5
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          2.0
# 10         NaN
# 11         NaN

# %%
salary = salary_data.drop(['Unnamed: 4', 'Unnamed: 5'], axis=1)

# %%
final_data = pd.merge(merged_df, salary, on='Position', how='inner')

# %%
final_data.head()
# Out:
#   First_Name   Last_Name  Employee_Number State   Zip        DOB  Age     Sex  \
# 0      Brown         Mia       1103024456    MA  1450 1985-11-24   32  Female
# 1  LaRotonda   William         1106026572    MA  1460 1984-04-26   33    Male
# 2     Steans    Tyrone         1302053333    MA  2703 1986-09-01   31    Male
# 3     Howard     Estelle       1211050782    MA  2170 1985-09-16   32  Female
# 4      Singh        Nan        1307059817    MA  2330 1988-05-19   29  Female
#
#   MaritalDesc CitizenDesc  ... MarriedID MaritalStatusID GenderID  \
# 0     Married  US Citizen  ...         1               1        0
# 1    Divorced  US Citizen  ...         0               2        1
# 2      Single  US Citizen  ...         0               0        1
# 3     Married  US Citizen  ...         1               1        0
# 4      Single  US Citizen  ...         0               0        0
#
#   EmpStatus_ID DeptID Perf_ScoreID Days_Employed    Min    Mid    Max
# 0            1      1            3          3317  42274  51425  62299
# 1            1      1            3          1420  42274  51425  62299
# 2            1      1            3          1154  42274  51425  62299
# 3            1      1            9            58  30000  40000  50000
# 4            1      1            9           940  30000  40000  50000
#
# [5 rows x 32 columns]

# %%
final_data.columns
# Out:
# Index(['First_Name', 'Last_Name', 'Employee_Number', 'State', 'Zip', 'DOB',
#        'Age', 'Sex', 'MaritalDesc', 'CitizenDesc', 'Hispanic_Latino',
#        'RaceDesc', 'Date_of_Hire', 'Date_of_Termination', 'Reason_For_Term',
#        'Employment_Status', 'Department', 'Position', 'Pay_Rate',
#        'Manager_Name', 'Employee_Source', 'Performance_Score', 'MarriedID',
#        'MaritalStatusID', 'GenderID', 'EmpStatus_ID', 'DeptID', 'Perf_ScoreID',
#        'Days_Employed', 'Min', 'Mid', 'Max'],
#       dtype='object')

# %% [markdown]
# ## Creating Schema for BigQuery Table

# %%
table_id = 'myworkingdataset.ETL_HR_Dataset'

job_config = bigquery.LoadJobConfig(
    schema=[
        bigquery.SchemaField('Employee_Number', 'INTEGER', mode='REQUIRED'),
        bigquery.SchemaField('First_Name', 'STRING'),
        bigquery.SchemaField('Last_Name', 'STRING'),
        bigquery.SchemaField('State', 'STRING'),
        bigquery.SchemaField('Zip', 'INTEGER'),
        bigquery.SchemaField('DOB', 'DATE'),
        bigquery.SchemaField('Age', 'INTEGER'),
        bigquery.SchemaField('Sex', 'STRING'),
        bigquery.SchemaField('MaritalDesc', 'STRING'),
        bigquery.SchemaField('CitizenDesc', 'STRING'),
        bigquery.SchemaField('Hispanic_Latino', 'STRING'),
        bigquery.SchemaField('RaceDesc', 'STRING'),
        bigquery.SchemaField('Date_of_Hire', 'DATE'),
        bigquery.SchemaField('Date_of_Termination', 'DATE'),
        bigquery.SchemaField('Reason_For_Term', 'STRING'),
        bigquery.SchemaField('Employment_Status', 'STRING'),
        bigquery.SchemaField('Department', 'STRING'),
        bigquery.SchemaField('Position', 'STRING'),
        bigquery.SchemaField('Pay_Rate', 'FLOAT'),
        bigquery.SchemaField('Manager_Name', 'STRING'),
        bigquery.SchemaField('Employee_Source', 'STRING'),
        bigquery.SchemaField('Performance_Score', 'STRING'),
        bigquery.SchemaField('MarriedID', 'INTEGER'),
        bigquery.SchemaField('MaritalStatusID', 'INTEGER'),
        bigquery.SchemaField('GenderID', 'INTEGER'),
        bigquery.SchemaField('EmpStatus_ID', 'INTEGER'),
        bigquery.SchemaField('DeptID', 'INTEGER'),
        bigquery.SchemaField('Perf_ScoreID', 'INTEGER'),
        bigquery.SchemaField('Days_Employed', 'INTEGER'),
        bigquery.SchemaField('Min', 'INTEGER'),
        bigquery.SchemaField('Mid', 'INTEGER'),
        bigquery.SchemaField('Max', 'INTEGER')
    ],
    write_disposition='WRITE_TRUNCATE' # Options: WRITE_APPEND, WRITE_TRUNCATE, WRITE_EMPTY
)

# %% [markdown]
# ## Loading the Dataframe into BigQuery Table

# %%
project_id1 = 'eighth-alchemy-382219'
client = bigquery.Client(project=project_id1, credentials=credentials1)
job = client.load_table_from_dataframe(final_data, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=eighth-alchemy-382219, location=US, id=3e36219f-9c71-4244-9bb3-6c85b12d39eb>

# %% [markdown]
# ## Querying Data from BigQuery Table

# %%
query = "select *  from myworkingdataset.ETL_HR_Dataset"
data = client.query(query, project=project_id1).to_dataframe()

# %%
data.head()
# Out:
#   First_Name  Last_Name  Employee_Number State   Zip         DOB  Age     Sex  \
# 0     Steans   Tyrone         1302053333    MA  2703  1986-09-01   31    Male
# 1      Singh       Nan        1307059817    MA  2330  1988-05-19   29  Female
# 2     Horton      Jayne       1105025718    MA  2493  1984-02-21   33  Female
# 3       Zhou      Julia       1110029732    MA  2148  1979-02-24   38  Female
# 4     Merlos     Carlos       1012023013    MA  2138  1987-06-18   30    Male
#
#   MaritalDesc CitizenDesc  ... MarriedID MaritalStatusID GenderID  \
# 0      Single  US Citizen  ...         0               0        1
# 1      Single  US Citizen  ...         0               0        0
# 2      Single  US Citizen  ...         0               0        0
# 3      Single  US Citizen  ...         0               0        0
# 4      Single  US Citizen  ...         0               0        1
#
#   EmpStatus_ID DeptID Perf_ScoreID Days_Employed    Min    Mid    Max
# 0            1      1            3          1154  42274  51425  62299
# 1            1      1            9           940  30000  40000  50000
# 2            1      3            9           972  50569  68306  93312
# 3            1      3            0           972  50569  68306  93312
# 4            1      3            9           972  50845  66850  88279
#
# [5 rows x 32 columns]

# %%
query = "SELECT * FROM myworkingdataset.ETL_HR_Dataset where Sex = 'Male' and MaritalDesc = 'Single'"
data = client.query(query, project=project_id1).to_dataframe()

# %%
data.head(40)
# Out:
#      First_Name      Last_Name  Employee_Number State   Zip         DOB  Age  \
# 0        Steans       Tyrone         1302053333    MA  2703  1986-09-01   31
# 1        Merlos         Carlos       1012023013    MA  2138  1987-06-18   30
# 2         South            Joe       1308060959    CT  6278  1965-09-09   52
# 3      Adinolfi      Wilson  K       1409070522    MA  1960  1983-07-10   34
# 4        Barone   Francesco  A       1101023679    MA  1810  1983-07-20   34
# 5     Bernstein           Sean       1109029366    MA  2072  1970-12-22   47
# 6         Chang     Donovan  E       1111030129    MA  1845  1983-08-24   34
# 7        Cockel          James       1599991009    MA  2452  1977-09-08   40
# 8     Dickinson         Geoff         706006285    MA  2180  1982-11-15   35
# 9       Engdahl           Jean       1007020403    MA  2026  1974-05-31   43
# 10       Garcia           Raul       1309061015    MA  1905  1985-09-15   32
# 11      Garneau         Hamish       1104025414    MA  1550  1980-04-18   37
# 12     Heitzman        Anthony       1002017900    MA  2149  1984-01-04   34
# 13       Keatts        Kramer        1301052462    MA  1887  1976-01-19   42
# 14        Knapp     Bradley  J       1304055683    MA  1721  1977-11-10   40
# 15         Owad        Clinton       1103024335    MA  1760  1979-11-24   38
# 16         Pitt          Brad        1001735072    MA  2451  1981-11-23   36
# 17     Punjabhi        Louis         1401064562    MA  2109  1961-06-19   56
# 18     Buccheri       Joseph         1101023457    MA  1013  1983-07-28   34
# 19        Davis         Daniel       1201031274    MA  2458  1979-09-14   38
# 20      Hankard        Earnest       1307059937    MA  2155  1988-08-10   29
# 21        Smith            Joe       1001970770    MA  2045  1963-10-30   54
# 22       Walker          Roger       1011022818    MA  2459  1976-02-10   41
# 23      Woodson          Jason       1012023010    MA  1810  1985-05-11   32
# 24       Becker          Scott       1110029777    MA  2452  1979-04-06   38
# 25        Moran        Patrick       1408069503    MA  2127  1976-12-03   41
# 26        Favis       Donald         1412071562    CT  6033  1964-07-30   53
# 27         Cole        Spencer       1001450968    MA  1880  1979-08-12   38
# 28    Estremera         Miguel       1104025243    MA  2129  1983-09-02   34
# 29        LeBel    Jonathan  R       1107027575    MA  2050  1981-10-18   36
# 30         Ndzi       Colombui       1204033041    MA  2110  1989-05-02   28
# 31         Ndzi       Colombui       1204033041    MA  2110  1989-05-02   28
# 32       Pelech           Emil       1307060058    MA  2458  1988-03-17   29
# 33     Rossetti          Bruno       1405067492    MA  2155  1987-03-18   30
# 34        Sadki         Nore         1308060535    MA  2148  1974-12-21   43
# 35     Whittier          Scott       1307060212    MA  2030  1987-05-24   30
# 36  Fitzpatrick     Michael  J       1109029103    MA  2143  1981-10-01   36
# 37       Miller            Ned       1205033439    MA  2472  1985-06-29   32
#
#      Sex MaritalDesc          CitizenDesc  ... MarriedID MaritalStatusID  \
# 0   Male      Single           US Citizen  ...         0               0
# 1   Male      Single           US Citizen  ...         0               0
# 2   Male      Single           US Citizen  ...         0               0
# 3   Male      Single           US Citizen  ...         0               0
# 4   Male      Single           US Citizen  ...         0               0
# 5   Male      Single           US Citizen  ...         0               0
# 6   Male      Single           US Citizen  ...         0               0
# 7   Male      Single           US Citizen  ...         0               0
# 8   Male      Single           US Citizen  ...         0               0
# 9   Male      Single           US Citizen  ...         0               0
# 10  Male      Single           US Citizen  ...         0               0
# 11  Male      Single           US Citizen  ...         0               0
# 12  Male      Single           US Citizen  ...         0               0
# 13  Male      Single           US Citizen  ...         0               0
# 14  Male      Single           US Citizen  ...         0               0
# 15  Male      Single           US Citizen  ...         0               0
# 16  Male      Single           US Citizen  ...         0               0
# 17  Male      Single           US Citizen  ...         0               0
# 18  Male      Single           US Citizen  ...         0               0
# 19  Male      Single  Eligible NonCitizen  ...         0               0
# 20  Male      Single           US Citizen  ...         0               0
# 21  Male      Single           US Citizen  ...         0               0
# 22  Male      Single           US Citizen  ...         0               0
# 23  Male      Single           US Citizen  ...         0               0
# 24  Male      Single           US Citizen  ...         0               0
# 25  Male      Single           US Citizen  ...         0               0
# 26  Male      Single           US Citizen  ...         0               0
# 27  Male      Single           US Citizen  ...         0               0
# 28  Male      Single           US Citizen  ...         0               0
# 29  Male      Single           US Citizen  ...         0               0
# 30  Male      Single           US Citizen  ...         0               0
# 31  Male      Single           US Citizen  ...         1               1
# 32  Male      Single           US Citizen  ...         0               0
# 33  Male      Single           US Citizen  ...         0               0
# 34  Male      Single           US Citizen  ...         0               0
# 35  Male      Single           US Citizen  ...         0               0
# 36  Male      Single           US Citizen  ...         0               0
# 37  Male      Single           US Citizen  ...         0               0
#
#    GenderID EmpStatus_ID DeptID Perf_ScoreID Days_Employed    Min     Mid  \
# 0         1            1      1            3          1154  42274   51425
# 1         1            1      3            9           972  50845   66850
# 2         1            1      3            0          1112  79428   99458
# 3         1            1      5            4          2336  30000   40000
# 4         1            1      5            3          2106  30000   40000
# 5         1            1      5            3          2064  30000   40000
# 6         1            1      5            3          1602  30000   40000
# 7         1            1      5            3          1602  30000   40000
# 8         1            1      5            3          1294  30000   40000
# 9         1            1      5            3          1112  30000   40000
# 10        1            1      5            9           972  30000   40000
# 11        1            1      5            3          1602  30000   40000
# 12        1            1      5            0          1931  30000   40000
# 13        1            1      5            3          1518  30000   40000
# 14        1            1      5            3          1378  30000   40000
# 15        1            1      5            2          1378  30000   40000
# 16        1            1      5            3          3674  30000   40000
# 17        1            1      5            3          1420  30000   40000
# 18        1            1      5            3          1154  38000   48000
# 19        1            1      5            0          2211  38000   48000
# 20        1            1      5            3          1476  38000   48000
# 21        1            1      5            4          1154  38000   48000
# 22        1            1      5            3          1196  38000   48000
# 23        1            1      5            3          1238  38000   48000
# 24        1            3      5            3          1602  30000   40000
# 25        1            3      5            3          2148  38000   48000
# 26        1            4      3            3           732  92863  116007
# 27        1            4      5            2           440  30000   40000
# 28        1            4      5            2           908  30000   40000
# 29        1            4      5            0           164  30000   40000
# 30        1            5      5            3           921  30000   40000
# 31        1            5      5            3          1150  30000   40000
# 32        1            5      5            2           718  30000   40000
# 33        1            5      5            3           497  30000   40000
# 34        1            5      5            3           571  30000   40000
# 35        1            5      5            0           125  30000   40000
# 36        1            5      5            3           770  38000   48000
# 37        1            5      5            1          1116  38000   48000
#
#        Max
# 0    62299
# 1    88279
# 2   120451
# 3    50000
# 4    50000
# 5    50000
# 6    50000
# 7    50000
# 8    50000
# 9    50000
# 10   50000
# 11   50000
# 12   50000
# 13   50000
# 14   50000
# 15   50000
# 16   50000
# 17   50000
# 18   58000
# 19   58000
# 20   58000
# 21   58000
# 22   58000
# 23   58000
# 24   50000
# 25   58000
# 26  139170
# 27   50000
# 28   50000
# 29   50000
# 30   50000
# 31   50000
# 32   50000
# 33   50000
# 34   50000
# 35   50000
# 36   58000
# 37   58000
#
# [38 rows x 32 columns]

# %%
query = "SELECT * FROM myworkingdataset.ETL_HR_Dataset where Sex = 'Male' and MaritalDesc = 'Single' and Age >30"
data = client.query(query, project=project_id1).to_dataframe()

# %%
data.head(50)
# Out:
#      First_Name      Last_Name  Employee_Number State   Zip         DOB  Age  \
# 0        Steans       Tyrone         1302053333    MA  2703  1986-09-01   31
# 1         South            Joe       1308060959    CT  6278  1965-09-09   52
# 2      Adinolfi      Wilson  K       1409070522    MA  1960  1983-07-10   34
# 3        Barone   Francesco  A       1101023679    MA  1810  1983-07-20   34
# 4     Bernstein           Sean       1109029366    MA  2072  1970-12-22   47
# 5         Chang     Donovan  E       1111030129    MA  1845  1983-08-24   34
# 6        Cockel          James       1599991009    MA  2452  1977-09-08   40
# 7     Dickinson         Geoff         706006285    MA  2180  1982-11-15   35
# 8       Engdahl           Jean       1007020403    MA  2026  1974-05-31   43
# 9        Garcia           Raul       1309061015    MA  1905  1985-09-15   32
# 10      Garneau         Hamish       1104025414    MA  1550  1980-04-18   37
# 11     Heitzman        Anthony       1002017900    MA  2149  1984-01-04   34
# 12       Keatts        Kramer        1301052462    MA  1887  1976-01-19   42
# 13        Knapp     Bradley  J       1304055683    MA  1721  1977-11-10   40
# 14         Owad        Clinton       1103024335    MA  1760  1979-11-24   38
# 15         Pitt          Brad        1001735072    MA  2451  1981-11-23   36
# 16     Punjabhi        Louis         1401064562    MA  2109  1961-06-19   56
# 17     Buccheri       Joseph         1101023457    MA  1013  1983-07-28   34
# 18        Davis         Daniel       1201031274    MA  2458  1979-09-14   38
# 19        Smith            Joe       1001970770    MA  2045  1963-10-30   54
# 20       Walker          Roger       1011022818    MA  2459  1976-02-10   41
# 21      Woodson          Jason       1012023010    MA  1810  1985-05-11   32
# 22       Becker          Scott       1110029777    MA  2452  1979-04-06   38
# 23        Moran        Patrick       1408069503    MA  2127  1976-12-03   41
# 24        Favis       Donald         1412071562    CT  6033  1964-07-30   53
# 25         Cole        Spencer       1001450968    MA  1880  1979-08-12   38
# 26    Estremera         Miguel       1104025243    MA  2129  1983-09-02   34
# 27        LeBel    Jonathan  R       1107027575    MA  2050  1981-10-18   36
# 28        Sadki         Nore         1308060535    MA  2148  1974-12-21   43
# 29  Fitzpatrick     Michael  J       1109029103    MA  2143  1981-10-01   36
# 30       Miller            Ned       1205033439    MA  2472  1985-06-29   32
#
#      Sex MaritalDesc          CitizenDesc  ... MarriedID MaritalStatusID  \
# 0   Male      Single           US Citizen  ...         0               0
# 1   Male      Single           US Citizen  ...         0               0
# 2   Male      Single           US Citizen  ...         0               0
# 3   Male      Single           US Citizen  ...         0               0
# 4   Male      Single           US Citizen  ...         0               0
# 5   Male      Single           US Citizen  ...         0               0
# 6   Male      Single           US Citizen  ...         0               0
# 7   Male      Single           US Citizen  ...         0               0
# 8   Male      Single           US Citizen  ...         0               0
# 9   Male      Single           US Citizen  ...         0               0
# 10  Male      Single           US Citizen  ...         0               0
# 11  Male      Single           US Citizen  ...         0               0
# 12  Male      Single           US Citizen  ...         0               0
# 13  Male      Single           US Citizen  ...         0               0
# 14  Male      Single           US Citizen  ...         0               0
# 15  Male      Single           US Citizen  ...         0               0
# 16  Male      Single           US Citizen  ...         0               0
# 17  Male      Single           US Citizen  ...         0               0
# 18  Male      Single  Eligible NonCitizen  ...         0               0
# 19  Male      Single           US Citizen  ...         0               0
# 20  Male      Single           US Citizen  ...         0               0
# 21  Male      Single           US Citizen  ...         0               0
# 22  Male      Single           US Citizen  ...         0               0
# 23  Male      Single           US Citizen  ...         0               0
# 24  Male      Single           US Citizen  ...         0               0
# 25  Male      Single           US Citizen  ...         0               0
# 26  Male      Single           US Citizen  ...         0               0
# 27  Male      Single           US Citizen  ...         0               0
# 28  Male      Single           US Citizen  ...         0               0
# 29  Male      Single           US Citizen  ...         0               0
# 30  Male      Single           US Citizen  ...         0               0
#
#    GenderID EmpStatus_ID DeptID Perf_ScoreID Days_Employed    Min     Mid  \
# 0         1            1      1            3          1154  42274   51425
# 1         1            1      3            0          1112  79428   99458
# 2         1            1      5            4          2336  30000   40000
# 3         1            1      5            3          2106  30000   40000
# 4         1            1      5            3          2064  30000   40000
# 5         1            1      5            3          1602  30000   40000
# 6         1            1      5            3          1602  30000   40000
# 7         1            1      5            3          1294  30000   40000
# 8         1            1      5            3          1112  30000   40000
# 9         1            1      5            9           972  30000   40000
# 10        1            1      5            3          1602  30000   40000
# 11        1            1      5            0          1931  30000   40000
# 12        1            1      5            3          1518  30000   40000
# 13        1            1      5            3          1378  30000   40000
# 14        1            1      5            2          1378  30000   40000
# 15        1            1      5            3          3674  30000   40000
# 16        1            1      5            3          1420  30000   40000
# 17        1            1      5            3          1154  38000   48000
# 18        1            1      5            0          2211  38000   48000
# 19        1            1      5            4          1154  38000   48000
# 20        1            1      5            3          1196  38000   48000
# 21        1            1      5            3          1238  38000   48000
# 22        1            3      5            3          1602  30000   40000
# 23        1            3      5            3          2148  38000   48000
# 24        1            4      3            3           732  92863  116007
# 25        1            4      5            2           440  30000   40000
# 26        1            4      5            2           908  30000   40000
# 27        1            4      5            0           164  30000   40000
# 28        1            5      5            3           571  30000   40000
# 29        1            5      5            3           770  38000   48000
# 30        1            5      5            1          1116  38000   48000
#
#        Max
# 0    62299
# 1   120451
# 2    50000
# 3    50000
# 4    50000
# 5    50000
# 6    50000
# 7    50000
# 8    50000
# 9    50000
# 10   50000
# 11   50000
# 12   50000
# 13   50000
# 14   50000
# 15   50000
# 16   50000
# 17   58000
# 18   58000
# 19   58000
# 20   58000
# 21   58000
# 22   50000
# 23   58000
# 24  139170
# 25   50000
# 26   50000
# 27   50000
# 28   50000
# 29   58000
# 30   58000
#
# [31 rows x 32 columns]
